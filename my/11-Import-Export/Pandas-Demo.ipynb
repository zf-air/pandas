# %%
import pandas as pd

# %%
df = pd.read_csv('E:/GitProjects/pandas/data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('E:/GitProjects/pandas/data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
#               CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1            European Euro            EUR   Microsoft SQL Server
# 2           Pound sterling            GBP                    NaN
# 3                      NaN            NaN                    NaN
# 4             Albanian lek            ALL                    NaN
# 5                      NaN            NaN       MySQL;PostgreSQL
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                       MySQL;PostgreSQL;Redis;SQLite
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
# 4                                                         NaN
# 5                                          Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 1           White or of European descent    Man
# 2                                    NaN    NaN
# 3                                    NaN    NaN
# 4           White or of European descent    Man
# 5           White or of European descent    Man
#
#                                                    JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies ...
# 2                                                         NaN
# 3                                                         NaN
# 4           Flex time or a flexible schedule;Office enviro...
# 5                                                         NaN
#
#                            JobSat  \
# Respondent
# 1              Slightly satisfied
# 2               Very dissatisfied
# 3                             NaN
# 4           Slightly dissatisfied
# 5                             NaN
#
#                                                       JobSeek  \
# Respondent
# 1                I am not interested in new job opportunities
# 2                I am not interested in new job opportunities
# 3                                                         NaN
# 4           I’m not actively looking, but I am open to new...
# 5                                                         NaN
#
#               LanguageDesireNextYear        LanguageWorkedWith  \
# Respondent
# 1             C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 2                       Python;Swift          JavaScript;Swift
# 3           Objective-C;Python;Swift  Objective-C;Python;Swift
# 4                                NaN                       NaN
# 5                    Java;Ruby;Scala         HTML/CSS;Ruby;SQL
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1                Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                         Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                         NaN       NaN
# 4                                                         NaN        No
# 5           Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
#
#                  NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 1           Somewhat important                    Fairly important
# 2                          NaN                    Fairly important
# 3                          NaN                                 NaN
# 4                          NaN  Not at all important/not necessary
# 5                          NaN                      Very important
#
#                                                    NEWJobHunt  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Curious about other opportunities;Wanting to w...
# 5                                                         NaN
#
#            NEWJobHuntResearch       NEWLearn NEWOffTopic NEWOnboardGood  \
# Respondent
# 1                         NaN    Once a year    Not sure            NaN
# 2                         NaN    Once a year    Not sure            NaN
# 3                         NaN  Once a decade         NaN            NaN
# 4                         NaN    Once a year    Not sure            Yes
# 5                         NaN    Once a year          No            NaN
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 1                     No                   Often: 1-2 days per week or more
# 2                     No                                                NaN
# 3                     No                                                NaN
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 5                    Yes                                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 1                      Amused
# 2                      Amused
# 3                         NaN
# 4                         NaN
# 5           Hello, old friend
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                              OrgSize  \
# Respondent
# 1                   2 to 9 employees
# 2           1,000 to 4,999 employees
# 3                                NaN
# 4                 20 to 99 employees
# 5                                NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
#
#                         PlatformWorkedWith                      PurchaseWhat  \
# Respondent
# 1                                  Windows                               NaN
# 2                                      iOS     I have little or no influence
# 3                                      NaN                               NaN
# 4                                      NaN  I have a great deal of influence
# 5           AWS;Docker;Linux;MacOS;Windows                               NaN
#
#                           Sexuality SOAccount           SOComm  \
# Respondent
# 1           Straight / Heterosexual        No   No, not at all
# 2                               NaN       Yes  Yes, definitely
# 3                               NaN       Yes    Yes, somewhat
# 4           Straight / Heterosexual       Yes  Yes, definitely
# 5           Straight / Heterosexual       Yes    Yes, somewhat
#
#                                      SOPartFreq  \
# Respondent
# 1                                           NaN
# 2           Less than once per month or monthly
# 3               A few times per month or weekly
# 4               A few times per month or weekly
# 5           Less than once per month or monthly
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 1                    Multiple times per day  Neither easy nor difficult
# 2                    Multiple times per day                         NaN
# 3                     Daily or almost daily  Neither easy nor difficult
# 4                    Multiple times per day                         NaN
# 5           A few times per month or weekly                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#            WebframeDesireNextYear    WebframeWorkedWith  \
# Respondent
# 1                    ASP.NET Core  ASP.NET;ASP.NET Core
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
# 5            Django;Ruby on Rails         Ruby on Rails
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
# 4           Somewhat less welcome now than last year         40.0         7
# 5            Just as welcome now as I felt last year          NaN        15
#
#            YearsCodePro
# Respondent
# 1                    27
# 2                     4
# 3                   NaN
# 4                     4
# 5                     8

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df.head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
#
#            CompFreq   CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 7           Monthly         NaN            NaN   India  United States dollar
# 22          Monthly         NaN            NaN   India          Indian rupee
# 58              NaN         NaN            NaN   India          Indian rupee
# 63              NaN         NaN            NaN   India                   NaN
# 149          Yearly  21000000.0       293196.0   India          Indian rupee
#
#            CurrencySymbol      DatabaseDesireNextYear      DatabaseWorkedWith  \
# Respondent
# 7                     USD                         NaN                     NaN
# 22                    INR                         NaN                     NaN
# 58                    INR        Microsoft SQL Server    Microsoft SQL Server
# 63                    NaN                    DynamoDB  Firebase;MongoDB;MySQL
# 149                   INR  Cassandra;MySQL;PostgreSQL        MySQL;PostgreSQL
#
#                                                       DevType  \
# Respondent
# 7           Developer, back-end;Developer, front-end;Devel...
# 22                       Developer, full-stack;Engineer, data
# 58                                        Developer, back-end
# 63          Designer;Developer, back-end;Developer, front-...
# 149         Developer, back-end;Developer, QA or test;DevO...
#
#                                                       EdLevel  \
# Respondent
# 7                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 22               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 58                                                        NaN
# 63          Secondary school (e.g. American high school, G...
# 149              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment    Ethnicity  \
# Respondent
# 7                                          Employed full-time          NaN
# 22                                         Employed full-time          NaN
# 58          Independent contractor, freelancer, or self-em...  South Asian
# 63                         Not employed, but looking for work  South Asian
# 149                                        Employed full-time   East Asian
#
#            Gender                                         JobFactors  \
# Respondent
# 7             NaN                                                NaN
# 22            Man                                                NaN
# 58            NaN                                Family friendliness
# 63            Man  Flex time or a flexible schedule;How widely us...
# 149           Man  Languages, frameworks, and other technologies ...
#
#                            JobSat  \
# Respondent
# 7                  Very satisfied
# 22          Slightly dissatisfied
# 58                 Very satisfied
# 63                            NaN
# 149                Very satisfied
#
#                                                       JobSeek  \
# Respondent
# 7           I’m not actively looking, but I am open to new...
# 22                            I am actively looking for a job
# 58               I am not interested in new job opportunities
# 63                            I am actively looking for a job
# 149              I am not interested in new job opportunities
#
#                                  LanguageDesireNextYear  \
# Respondent
# 7                                       C#;HTML/CSS;PHP
# 22                               Java;JavaScript;Python
# 58                         C#;JavaScript;SQL;TypeScript
# 63                                 Go;Kotlin;TypeScript
# 149         Bash/Shell/PowerShell;C;C++;Java;Perl;Scala
#
#                                LanguageWorkedWith  \
# Respondent
# 7                                 C#;HTML/CSS;PHP
# 22                                    Java;Python
# 58                   C#;JavaScript;SQL;TypeScript
# 63          C;C++;HTML/CSS;Java;JavaScript;Python
# 149                Bash/Shell/PowerShell;C++;Perl
#
#                              MiscTechDesireNextYear      MiscTechWorkedWith  \
# Respondent
# 7                                               NaN                     NaN
# 22                                              NaN                     NaN
# 58                           .NET;.NET Core;Node.js  .NET;.NET Core;Node.js
# 63          Flutter;Node.js;React Native;TensorFlow                     NaN
# 149                                    Apache Spark                     NaN
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 7                                                         NaN
# 22                                                        NaN
# 58                                   Stack Overflow for Teams
# 63                        Confluence;Stack Overflow for Teams
# 149         Confluence;Jira;Github;Gitlab;Google Suite (Do...
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 7                                                         NaN       Yes
# 22                                                        NaN  Not sure
# 58                                   Stack Overflow for Teams       Yes
# 63          Github;Facebook Workplace;Slack;Microsoft Team...       NaN
# 149         Confluence;Jira;Github;Google Suite (Docs, Mee...  Not sure
#
#                   NEWDevOpsImpt             NEWEdImpt  \
# Respondent
# 7           Extremely important        Very important
# 22                          NaN        Very important
# 58          Extremely important        Very important
# 63                          NaN                   NaN
# 149                     Neutral  Critically important
#
#                                                    NEWJobHunt  \
# Respondent
# 7           Better compensation;Growth or leadership oppor...
# 22          Better compensation;Better work/life balance;W...
# 58                                                        NaN
# 63                                                        NaN
# 149         Just because;Curious about other opportunities...
#
#                                            NEWJobHuntResearch  \
# Respondent
# 7           Read company media, such as employee blogs or ...
# 22          Company reviews from third party sites (e.g. G...
# 58                                                        NaN
# 63                                                        NaN
# 149         Read company media, such as employee blogs or ...
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 7               Every few months         Yes                           Yes
# 22              Every few months          No                           Yes
# 58          Once every few years         NaN                           Yes
# 63                   Once a year         Yes                           NaN
# 149                  Once a year    Not sure  Onboarding? What onboarding?
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 7                     No  Sometimes: 1-2 days per month but less than we...
# 22                    No                   Often: 1-2 days per week or more
# 58                    No                   Often: 1-2 days per week or more
# 63                    No                                                NaN
# 149                   No  Sometimes: 1-2 days per month but less than we...
#
#                                           NEWPurchaseResearch  \
# Respondent
# 7           Start a free trial;Ask developers I know/work ...
# 22                                                        NaN
# 58                            Ask developers I know/work with
# 63          Start a free trial;Ask developers I know/work ...
# 149                                                       NaN
#
#                 NEWPurpleLink  \
# Respondent
# 7                         NaN
# 22                        NaN
# 58          Hello, old friend
# 63          Hello, old friend
# 149               Indifferent
#
#                                                    NEWSOSites  \
# Respondent
# 7            Stack Overflow (public Q&A for anyone who codes)
# 22          Stack Overflow (public Q&A for anyone who code...
# 58          Stack Overflow (public Q&A for anyone who code...
# 63          Stack Overflow (public Q&A for anyone who code...
# 149          Stack Overflow (public Q&A for anyone who codes)
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 7                                                         NaN      Windows
# 22                                                        NaN      Windows
# 58          Call a coworker or friend;Visit Stack Overflow...      Windows
# 63          Visit Stack Overflow;Go for a walk or other ph...      Windows
# 149         Visit Stack Overflow;Go for a walk or other ph...  Linux-based
#
#                          OrgSize       PlatformDesireNextYear  \
# Respondent
# 7             20 to 99 employees                          NaN
# 22          500 to 999 employees                          NaN
# 58                           NaN                          NaN
# 63                           NaN        AWS;Docker;Heroku;iOS
# 149         500 to 999 employees  Google Cloud Platform;Linux
#
#                                            PlatformWorkedWith  \
# Respondent
# 7                                                         NaN
# 22                                                        NaN
# 58                                                        NaN
# 63          Android;Arduino;Google Cloud Platform;Raspberr...
# 149                                                     Linux
#
#                              PurchaseWhat                Sexuality SOAccount  \
# Respondent
# 7                                     NaN                      NaN       Yes
# 22                                    NaN                      NaN       Yes
# 58                                    NaN                      NaN       Yes
# 63                                    NaN  Straight / Heterosexual       Yes
# 149         I have little or no influence  Straight / Heterosexual       Yes
#
#                      SOComm                       SOPartFreq  \
# Respondent
# 7           Yes, definitely           Multiple times per day
# 22          Yes, definitely           Multiple times per day
# 58          Yes, definitely                              NaN
# 63                  Neutral             A few times per week
# 149           Yes, somewhat  A few times per month or weekly
#
#                        SOVisitFreq                  SurveyEase  \
# Respondent
# 7           Multiple times per day                         NaN
# 22          Multiple times per day                        Easy
# 58          Multiple times per day  Neither easy nor difficult
# 63           Daily or almost daily                        Easy
# 149         Multiple times per day  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# 7                             NaN   NaN
# 22          Appropriate in length   NaN
# 58                       Too long   NaN
# 63          Appropriate in length    No
# 149         Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 7           Computer science, computer engineering, or sof...
# 22          Computer science, computer engineering, or sof...
# 58                              Web development or web design
# 63                                                        NaN
# 149         Computer science, computer engineering, or sof...
#
#                                     WebframeDesireNextYear  \
# Respondent
# 7                                                      NaN
# 22                                                     NaN
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 63                 Angular.js;Django;jQuery;Laravel;Vue.js
# 149                                                    NaN
#
#                                         WebframeWorkedWith  \
# Respondent
# 7                                                      NaN
# 22                                                     NaN
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 63                                                     NaN
# 149                                                    NaN
#
#                                                 WelcomeChange  WorkWeekHrs  \
# Respondent
# 7                       A lot more welcome now than last year          NaN
# 22                    Just as welcome now as I felt last year         50.0
# 58                                                        NaN          NaN
# 63          Not applicable - I did not use Stack Overflow ...          NaN
# 149                  Somewhat more welcome now than last year         70.0
#
#            YearsCode YearsCodePro
# Respondent
# 7                  6            4
# 22                10            2
# 58               NaN          NaN
# 63                 4          NaN
# 149                5            3

# %% [markdown]
# ### 转换为csv和tsv文件

# %%
india_df.to_csv('modified.csv')

# %%
india_df.to_csv('modified.tsv', sep='\t')

# %% [markdown]
# ### 转换为xlsx文件，用excel打开

# %%
india_df.to_excel('modified.xlsx')

# %%
test = pd.read_excel('modified.xlsx', index_col='Respondent')

# %%
test.head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
#
#            CompFreq   CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 7           Monthly         NaN            NaN   India  United States dollar
# 22          Monthly         NaN            NaN   India          Indian rupee
# 58              NaN         NaN            NaN   India          Indian rupee
# 63              NaN         NaN            NaN   India                   NaN
# 149          Yearly  21000000.0       293196.0   India          Indian rupee
#
#            CurrencySymbol      DatabaseDesireNextYear      DatabaseWorkedWith  \
# Respondent
# 7                     USD                         NaN                     NaN
# 22                    INR                         NaN                     NaN
# 58                    INR        Microsoft SQL Server    Microsoft SQL Server
# 63                    NaN                    DynamoDB  Firebase;MongoDB;MySQL
# 149                   INR  Cassandra;MySQL;PostgreSQL        MySQL;PostgreSQL
#
#                                                       DevType  \
# Respondent
# 7           Developer, back-end;Developer, front-end;Devel...
# 22                       Developer, full-stack;Engineer, data
# 58                                        Developer, back-end
# 63          Designer;Developer, back-end;Developer, front-...
# 149         Developer, back-end;Developer, QA or test;DevO...
#
#                                                       EdLevel  \
# Respondent
# 7                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 22               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 58                                                        NaN
# 63          Secondary school (e.g. American high school, G...
# 149              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment    Ethnicity  \
# Respondent
# 7                                          Employed full-time          NaN
# 22                                         Employed full-time          NaN
# 58          Independent contractor, freelancer, or self-em...  South Asian
# 63                         Not employed, but looking for work  South Asian
# 149                                        Employed full-time   East Asian
#
#            Gender                                         JobFactors  \
# Respondent
# 7             NaN                                                NaN
# 22            Man                                                NaN
# 58            NaN                                Family friendliness
# 63            Man  Flex time or a flexible schedule;How widely us...
# 149           Man  Languages, frameworks, and other technologies ...
#
#                            JobSat  \
# Respondent
# 7                  Very satisfied
# 22          Slightly dissatisfied
# 58                 Very satisfied
# 63                            NaN
# 149                Very satisfied
#
#                                                       JobSeek  \
# Respondent
# 7           I’m not actively looking, but I am open to new...
# 22                            I am actively looking for a job
# 58               I am not interested in new job opportunities
# 63                            I am actively looking for a job
# 149              I am not interested in new job opportunities
#
#                                  LanguageDesireNextYear  \
# Respondent
# 7                                       C#;HTML/CSS;PHP
# 22                               Java;JavaScript;Python
# 58                         C#;JavaScript;SQL;TypeScript
# 63                                 Go;Kotlin;TypeScript
# 149         Bash/Shell/PowerShell;C;C++;Java;Perl;Scala
#
#                                LanguageWorkedWith  \
# Respondent
# 7                                 C#;HTML/CSS;PHP
# 22                                    Java;Python
# 58                   C#;JavaScript;SQL;TypeScript
# 63          C;C++;HTML/CSS;Java;JavaScript;Python
# 149                Bash/Shell/PowerShell;C++;Perl
#
#                              MiscTechDesireNextYear      MiscTechWorkedWith  \
# Respondent
# 7                                               NaN                     NaN
# 22                                              NaN                     NaN
# 58                           .NET;.NET Core;Node.js  .NET;.NET Core;Node.js
# 63          Flutter;Node.js;React Native;TensorFlow                     NaN
# 149                                    Apache Spark                     NaN
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 7                                                         NaN
# 22                                                        NaN
# 58                                   Stack Overflow for Teams
# 63                        Confluence;Stack Overflow for Teams
# 149         Confluence;Jira;Github;Gitlab;Google Suite (Do...
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 7                                                         NaN       Yes
# 22                                                        NaN  Not sure
# 58                                   Stack Overflow for Teams       Yes
# 63          Github;Facebook Workplace;Slack;Microsoft Team...       NaN
# 149         Confluence;Jira;Github;Google Suite (Docs, Mee...  Not sure
#
#                   NEWDevOpsImpt             NEWEdImpt  \
# Respondent
# 7           Extremely important        Very important
# 22                          NaN        Very important
# 58          Extremely important        Very important
# 63                          NaN                   NaN
# 149                     Neutral  Critically important
#
#                                                    NEWJobHunt  \
# Respondent
# 7           Better compensation;Growth or leadership oppor...
# 22          Better compensation;Better work/life balance;W...
# 58                                                        NaN
# 63                                                        NaN
# 149         Just because;Curious about other opportunities...
#
#                                            NEWJobHuntResearch  \
# Respondent
# 7           Read company media, such as employee blogs or ...
# 22          Company reviews from third party sites (e.g. G...
# 58                                                        NaN
# 63                                                        NaN
# 149         Read company media, such as employee blogs or ...
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 7               Every few months         Yes                           Yes
# 22              Every few months          No                           Yes
# 58          Once every few years         NaN                           Yes
# 63                   Once a year         Yes                           NaN
# 149                  Once a year    Not sure  Onboarding? What onboarding?
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 7                     No  Sometimes: 1-2 days per month but less than we...
# 22                    No                   Often: 1-2 days per week or more
# 58                    No                   Often: 1-2 days per week or more
# 63                    No                                                NaN
# 149                   No  Sometimes: 1-2 days per month but less than we...
#
#                                           NEWPurchaseResearch  \
# Respondent
# 7           Start a free trial;Ask developers I know/work ...
# 22                                                        NaN
# 58                            Ask developers I know/work with
# 63          Start a free trial;Ask developers I know/work ...
# 149                                                       NaN
#
#                 NEWPurpleLink  \
# Respondent
# 7                         NaN
# 22                        NaN
# 58          Hello, old friend
# 63          Hello, old friend
# 149               Indifferent
#
#                                                    NEWSOSites  \
# Respondent
# 7            Stack Overflow (public Q&A for anyone who codes)
# 22          Stack Overflow (public Q&A for anyone who code...
# 58          Stack Overflow (public Q&A for anyone who code...
# 63          Stack Overflow (public Q&A for anyone who code...
# 149          Stack Overflow (public Q&A for anyone who codes)
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 7                                                         NaN      Windows
# 22                                                        NaN      Windows
# 58          Call a coworker or friend;Visit Stack Overflow...      Windows
# 63          Visit Stack Overflow;Go for a walk or other ph...      Windows
# 149         Visit Stack Overflow;Go for a walk or other ph...  Linux-based
#
#                          OrgSize       PlatformDesireNextYear  \
# Respondent
# 7             20 to 99 employees                          NaN
# 22          500 to 999 employees                          NaN
# 58                           NaN                          NaN
# 63                           NaN        AWS;Docker;Heroku;iOS
# 149         500 to 999 employees  Google Cloud Platform;Linux
#
#                                            PlatformWorkedWith  \
# Respondent
# 7                                                         NaN
# 22                                                        NaN
# 58                                                        NaN
# 63          Android;Arduino;Google Cloud Platform;Raspberr...
# 149                                                     Linux
#
#                              PurchaseWhat                Sexuality SOAccount  \
# Respondent
# 7                                     NaN                      NaN       Yes
# 22                                    NaN                      NaN       Yes
# 58                                    NaN                      NaN       Yes
# 63                                    NaN  Straight / Heterosexual       Yes
# 149         I have little or no influence  Straight / Heterosexual       Yes
#
#                      SOComm                       SOPartFreq  \
# Respondent
# 7           Yes, definitely           Multiple times per day
# 22          Yes, definitely           Multiple times per day
# 58          Yes, definitely                              NaN
# 63                  Neutral             A few times per week
# 149           Yes, somewhat  A few times per month or weekly
#
#                        SOVisitFreq                  SurveyEase  \
# Respondent
# 7           Multiple times per day                         NaN
# 22          Multiple times per day                        Easy
# 58          Multiple times per day  Neither easy nor difficult
# 63           Daily or almost daily                        Easy
# 149         Multiple times per day  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# 7                             NaN   NaN
# 22          Appropriate in length   NaN
# 58                       Too long   NaN
# 63          Appropriate in length    No
# 149         Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 7           Computer science, computer engineering, or sof...
# 22          Computer science, computer engineering, or sof...
# 58                              Web development or web design
# 63                                                        NaN
# 149         Computer science, computer engineering, or sof...
#
#                                     WebframeDesireNextYear  \
# Respondent
# 7                                                      NaN
# 22                                                     NaN
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 63                 Angular.js;Django;jQuery;Laravel;Vue.js
# 149                                                    NaN
#
#                                         WebframeWorkedWith  \
# Respondent
# 7                                                      NaN
# 22                                                     NaN
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 63                                                     NaN
# 149                                                    NaN
#
#                                                 WelcomeChange  WorkWeekHrs  \
# Respondent
# 7                       A lot more welcome now than last year          NaN
# 22                    Just as welcome now as I felt last year         50.0
# 58                                                        NaN          NaN
# 63          Not applicable - I did not use Stack Overflow ...          NaN
# 149                  Somewhat more welcome now than last year         70.0
#
#            YearsCode YearsCodePro
# Respondent
# 7                  6            4
# 22                10            2
# 58               NaN          NaN
# 63                 4          NaN
# 149                5            3

# %% [markdown]
# ### 转换为json文件

# %%
india_df.to_json('modified.json', orient='records', lines=True)

# %%
test = pd.read_json('modified.json', orient='records', lines=True)

# %%
test.head()
# Out:
#                                MainBranch Hobbyist   Age Age1stCode CompFreq  \
# 0          I am a developer by profession      Yes   NaN         18  Monthly
# 1          I am a developer by profession      Yes   NaN         18  Monthly
# 2          I am a developer by profession      Yes   NaN         22     None
# 3  I am a student who is learning to code      Yes  21.0         17     None
# 4          I am a developer by profession      Yes  36.0         31   Yearly
#
#     CompTotal  ConvertedComp Country          CurrencyDesc CurrencySymbol  \
# 0         NaN            NaN   India  United States dollar            USD
# 1         NaN            NaN   India          Indian rupee            INR
# 2         NaN            NaN   India          Indian rupee            INR
# 3         NaN            NaN   India                  None           None
# 4  21000000.0       293196.0   India          Indian rupee            INR
#
#        DatabaseDesireNextYear      DatabaseWorkedWith  \
# 0                        None                    None
# 1                        None                    None
# 2        Microsoft SQL Server    Microsoft SQL Server
# 3                    DynamoDB  Firebase;MongoDB;MySQL
# 4  Cassandra;MySQL;PostgreSQL        MySQL;PostgreSQL
#
#                                              DevType  \
# 0  Developer, back-end;Developer, front-end;Devel...
# 1               Developer, full-stack;Engineer, data
# 2                                Developer, back-end
# 3  Designer;Developer, back-end;Developer, front-...
# 4  Developer, back-end;Developer, QA or test;DevO...
#
#                                              EdLevel  \
# 0       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                               None
# 3  Secondary school (e.g. American high school, G...
# 4       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment    Ethnicity Gender  \
# 0                                 Employed full-time         None   None
# 1                                 Employed full-time         None    Man
# 2  Independent contractor, freelancer, or self-em...  South Asian   None
# 3                 Not employed, but looking for work  South Asian    Man
# 4                                 Employed full-time   East Asian    Man
#
#                                           JobFactors                 JobSat  \
# 0                                               None         Very satisfied
# 1                                               None  Slightly dissatisfied
# 2                                Family friendliness         Very satisfied
# 3  Flex time or a flexible schedule;How widely us...                   None
# 4  Languages, frameworks, and other technologies ...         Very satisfied
#
#                                              JobSeek  \
# 0  I’m not actively looking, but I am open to new...
# 1                    I am actively looking for a job
# 2       I am not interested in new job opportunities
# 3                    I am actively looking for a job
# 4       I am not interested in new job opportunities
#
#                         LanguageDesireNextYear  \
# 0                              C#;HTML/CSS;PHP
# 1                       Java;JavaScript;Python
# 2                 C#;JavaScript;SQL;TypeScript
# 3                         Go;Kotlin;TypeScript
# 4  Bash/Shell/PowerShell;C;C++;Java;Perl;Scala
#
#                       LanguageWorkedWith  \
# 0                        C#;HTML/CSS;PHP
# 1                            Java;Python
# 2           C#;JavaScript;SQL;TypeScript
# 3  C;C++;HTML/CSS;Java;JavaScript;Python
# 4         Bash/Shell/PowerShell;C++;Perl
#
#                     MiscTechDesireNextYear      MiscTechWorkedWith  \
# 0                                     None                    None
# 1                                     None                    None
# 2                   .NET;.NET Core;Node.js  .NET;.NET Core;Node.js
# 3  Flutter;Node.js;React Native;TensorFlow                    None
# 4                             Apache Spark                    None
#
#                         NEWCollabToolsDesireNextYear  \
# 0                                               None
# 1                                               None
# 2                           Stack Overflow for Teams
# 3                Confluence;Stack Overflow for Teams
# 4  Confluence;Jira;Github;Gitlab;Google Suite (Do...
#
#                             NEWCollabToolsWorkedWith NEWDevOps  \
# 0                                               None       Yes
# 1                                               None  Not sure
# 2                           Stack Overflow for Teams       Yes
# 3  Github;Facebook Workplace;Slack;Microsoft Team...      None
# 4  Confluence;Jira;Github;Google Suite (Docs, Mee...  Not sure
#
#          NEWDevOpsImpt             NEWEdImpt  \
# 0  Extremely important        Very important
# 1                 None        Very important
# 2  Extremely important        Very important
# 3                 None                  None
# 4              Neutral  Critically important
#
#                                           NEWJobHunt  \
# 0  Better compensation;Growth or leadership oppor...
# 1  Better compensation;Better work/life balance;W...
# 2                                               None
# 3                                               None
# 4  Just because;Curious about other opportunities...
#
#                                   NEWJobHuntResearch              NEWLearn  \
# 0  Read company media, such as employee blogs or ...      Every few months
# 1  Company reviews from third party sites (e.g. G...      Every few months
# 2                                               None  Once every few years
# 3                                               None           Once a year
# 4  Read company media, such as employee blogs or ...           Once a year
#
#   NEWOffTopic                NEWOnboardGood NEWOtherComms  \
# 0         Yes                           Yes            No
# 1          No                           Yes            No
# 2        None                           Yes            No
# 3         Yes                          None            No
# 4    Not sure  Onboarding? What onboarding?            No
#
#                                          NEWOvertime  \
# 0  Sometimes: 1-2 days per month but less than we...
# 1                   Often: 1-2 days per week or more
# 2                   Often: 1-2 days per week or more
# 3                                               None
# 4  Sometimes: 1-2 days per month but less than we...
#
#                                  NEWPurchaseResearch      NEWPurpleLink  \
# 0  Start a free trial;Ask developers I know/work ...               None
# 1                                               None               None
# 2                    Ask developers I know/work with  Hello, old friend
# 3  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 4                                               None        Indifferent
#
#                                           NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who codes)
# 1  Stack Overflow (public Q&A for anyone who code...
# 2  Stack Overflow (public Q&A for anyone who code...
# 3  Stack Overflow (public Q&A for anyone who code...
# 4   Stack Overflow (public Q&A for anyone who codes)
#
#                                             NEWStuck        OpSys  \
# 0                                               None      Windows
# 1                                               None      Windows
# 2  Call a coworker or friend;Visit Stack Overflow...      Windows
# 3  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 4  Visit Stack Overflow;Go for a walk or other ph...  Linux-based
#
#                 OrgSize       PlatformDesireNextYear  \
# 0    20 to 99 employees                         None
# 1  500 to 999 employees                         None
# 2                  None                         None
# 3                  None        AWS;Docker;Heroku;iOS
# 4  500 to 999 employees  Google Cloud Platform;Linux
#
#                                   PlatformWorkedWith  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  Android;Arduino;Google Cloud Platform;Raspberr...
# 4                                              Linux
#
#                     PurchaseWhat                Sexuality SOAccount  \
# 0                           None                     None       Yes
# 1                           None                     None       Yes
# 2                           None                     None       Yes
# 3                           None  Straight / Heterosexual       Yes
# 4  I have little or no influence  Straight / Heterosexual       Yes
#
#             SOComm                       SOPartFreq             SOVisitFreq  \
# 0  Yes, definitely           Multiple times per day  Multiple times per day
# 1  Yes, definitely           Multiple times per day  Multiple times per day
# 2  Yes, definitely                             None  Multiple times per day
# 3          Neutral             A few times per week   Daily or almost daily
# 4    Yes, somewhat  A few times per month or weekly  Multiple times per day
#
#                    SurveyEase           SurveyLength Trans  \
# 0                        None                   None  None
# 1                        Easy  Appropriate in length  None
# 2  Neither easy nor difficult               Too long  None
# 3                        Easy  Appropriate in length    No
# 4  Neither easy nor difficult  Appropriate in length    No
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Computer science, computer engineering, or sof...
# 2                      Web development or web design
# 3                                               None
# 4  Computer science, computer engineering, or sof...
#
#                            WebframeDesireNextYear  \
# 0                                            None
# 1                                            None
# 2  Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 3         Angular.js;Django;jQuery;Laravel;Vue.js
# 4                                            None
#
#                                WebframeWorkedWith  \
# 0                                            None
# 1                                            None
# 2  Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 3                                            None
# 4                                            None
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# 0              A lot more welcome now than last year          NaN         6
# 1            Just as welcome now as I felt last year         50.0        10
# 2                                               None          NaN      None
# 3  Not applicable - I did not use Stack Overflow ...          NaN         4
# 4           Somewhat more welcome now than last year         70.0         5
#
#   YearsCodePro
# 0            4
# 1            2
# 2         None
# 3         None
# 4            3

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
india_df.to_sql('sample_table', engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     488     def connect(self, *cargs, **cparams):
# --> 489         return self.dbapi.connect(*cargs, **cparams)
#     490
#
# E:\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-16-a7b3701660b0> in <module>
# ----> 1 india_df.to_sql('sample_table', engine, if_exists='replace')
#
# E:\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# E:\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# E:\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# E:\Anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     642
#     643     def create(self):
# --> 644         if self.exists():
#     645             if self.if_exists == "fail":
#     646                 raise ValueError(f"Table '{self.name}' already exists.")
#
# E:\Anaconda3\lib\site-packages\pandas\io\sql.py in exists(self)
#     629
#     630     def exists(self):
# --> 631         return self.pd_sql.has_table(self.name, self.schema)
#     632
#     633     def sql_schema(self):
#
# E:\Anaconda3\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1339     def has_table(self, name, schema=None):
#    1340         return self.connectable.run_callable(
# -> 1341             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1342         )
#    1343
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2160
#    2161         """
# -> 2162         with self._contextual_connect() as conn:
#    2163             return conn.run_callable(callable_, *args, **kwargs)
#    2164
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2240         return self._connection_cls(
#    2241             self,
# -> 2242             self._wrap_pool_connect(self.pool.connect, None),
#    2243             close_with_result=close_with_result,
#    2244             **kwargs
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2278             if connection is None:
#    2279                 Connection._handle_dbapi_exception_noconnection(
# -> 2280                     e, dialect, self
#    2281                 )
#    2282             else:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1545             util.raise_from_cause(newraise, exc_info)
#    1546         elif should_wrap:
# -> 1547             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1548         else:
#    1549             util.reraise(*exc_info)
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         dialect = self.dialect
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#    2278             if connection is None:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     771     def _checkout(cls, pool, threadconns=None, fairy=None):
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#     775             fairy._pool = pool
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     650         try:
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#     654             self.connection = connection
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     487
#     488     def connect(self, *cargs, **cparams):
# --> 489         return self.dbapi.connect(*cargs, **cparams)
#     490
#     491     def create_connect_args(self, url):
#
# E:\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     488     def connect(self, *cargs, **cparams):
# --> 489         return self.dbapi.connect(*cargs, **cparams)
#     490
#
# E:\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-17-827c25942eaa> in <module>
# ----> 1 sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')
#
# E:\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     436             coerce_float=coerce_float,
#     437             parse_dates=parse_dates,
# --> 438             chunksize=chunksize,
#     439         )
#     440
#
# E:\Anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# E:\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2179         """
#    2180
# -> 2181         connection = self._contextual_connect(close_with_result=True)
#    2182         return connection.execute(statement, *multiparams, **params)
#    2183
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2240         return self._connection_cls(
#    2241             self,
# -> 2242             self._wrap_pool_connect(self.pool.connect, None),
#    2243             close_with_result=close_with_result,
#    2244             **kwargs
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2278             if connection is None:
#    2279                 Connection._handle_dbapi_exception_noconnection(
# -> 2280                     e, dialect, self
#    2281                 )
#    2282             else:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1545             util.raise_from_cause(newraise, exc_info)
#    1546         elif should_wrap:
# -> 1547             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1548         else:
#    1549             util.reraise(*exc_info)
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         dialect = self.dialect
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#    2278             if connection is None:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     771     def _checkout(cls, pool, threadconns=None, fairy=None):
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#     775             fairy._pool = pool
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     650         try:
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#     654             self.connection = connection
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     487
#     488     def connect(self, *cargs, **cparams):
# --> 489         return self.dbapi.connect(*cargs, **cparams)
#     490
#     491     def create_connect_args(self, url):
#
# E:\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
sql_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a6eb23911d9d> in <module>
# ----> 1 sql_df.head()
#
# NameError: name 'sql_df' is not defined

# %%
sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col='Respondent')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     488     def connect(self, *cargs, **cparams):
# --> 489         return self.dbapi.connect(*cargs, **cparams)
#     490
#
# E:\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-19-5ac740dbf619> in <module>
# ----> 1 sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col='Respondent')
#
# E:\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# E:\Anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# E:\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2179         """
#    2180
# -> 2181         connection = self._contextual_connect(close_with_result=True)
#    2182         return connection.execute(statement, *multiparams, **params)
#    2183
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2240         return self._connection_cls(
#    2241             self,
# -> 2242             self._wrap_pool_connect(self.pool.connect, None),
#    2243             close_with_result=close_with_result,
#    2244             **kwargs
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2278             if connection is None:
#    2279                 Connection._handle_dbapi_exception_noconnection(
# -> 2280                     e, dialect, self
#    2281                 )
#    2282             else:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1545             util.raise_from_cause(newraise, exc_info)
#    1546         elif should_wrap:
# -> 1547             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1548         else:
#    1549             util.reraise(*exc_info)
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         dialect = self.dialect
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#    2278             if connection is None:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     771     def _checkout(cls, pool, threadconns=None, fairy=None):
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#     775             fairy._pool = pool
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     650         try:
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#     654             self.connection = connection
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# E:\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     487
#     488     def connect(self, *cargs, **cparams):
# --> 489         return self.dbapi.connect(*cargs, **cparams)
#     490
#     491     def create_connect_args(self, url):
#
# E:\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
sql_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a6eb23911d9d> in <module>
# ----> 1 sql_df.head()
#
# NameError: name 'sql_df' is not defined

# %% [markdown]
# ### 读取json文件

# %%
posts_df = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# E:\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# E:\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# E:\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# E:\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# E:\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# E:\Anaconda3\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# E:\Anaconda3\lib\http\client.py in connect(self)
#    1413
# -> 1414             super().connect()
#    1415
#
# E:\Anaconda3\lib\http\client.py in connect(self)
#     937         self.sock = self._create_connection(
# --> 938             (self.host,self.port), self.timeout, self.source_address)
#     939         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# E:\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# E:\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     751     addrlist = []
# --> 752     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     753         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11004] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-21-970bfb0bdb56> in <module>
# ----> 1 posts_df = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')
#
# E:\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# E:\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     583     compression = infer_compression(path_or_buf, compression)
#     584     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 585         path_or_buf, encoding=encoding, compression=compression
#     586     )
#     587
#
# E:\Anaconda3\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     170
#     171     if isinstance(filepath_or_buffer, str) and is_url(filepath_or_buffer):
# --> 172         req = urlopen(filepath_or_buffer)
#     173         content_encoding = req.headers.get("Content-Encoding", None)
#     174         if content_encoding == "gzip":
#
# E:\Anaconda3\lib\site-packages\pandas\io\common.py in urlopen(*args, **kwargs)
#     139     import urllib.request
#     140
# --> 141     return urllib.request.urlopen(*args, **kwargs)
#     142
#     143
#
# E:\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# E:\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# E:\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# E:\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# E:\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1360         def https_open(self, req):
#    1361             return self.do_open(http.client.HTTPSConnection, req,
# -> 1362                 context=self._context, check_hostname=self._check_hostname)
#    1363
#    1364         https_request = AbstractHTTPHandler.do_request_
#
# E:\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
# -> 1321                 raise URLError(err)
#    1322             r = h.getresponse()
#    1323         except:
#
# URLError: <urlopen error [Errno 11004] getaddrinfo failed>

# %%
posts_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-90603007ec3f> in <module>
# ----> 1 posts_df.head()
#
# NameError: name 'posts_df' is not defined

# %%
pd.read_excel('modified.xlsx')
# Out:
# .
# 8398                                 Employed full-time          NaN    Man
# 8399                                                NaN          NaN    NaN
# 8400                                                NaN          NaN    Man
# 8401                                 Employed full-time          NaN    NaN
# 8402                                 Employed full-time          NaN    NaN
#
#                                              JobFactors  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                   Family friendliness
# 3     Flex time or a flexible schedule;How widely us...
# 4     Languages, frameworks, and other technologies ...
# ...                                                 ...
# 8398                                                NaN
# 8399                                                NaN
# 8400                                                NaN
# 8401                                                NaN
# 8402                                                NaN
#
#                      JobSat  \
# 0            Very satisfied
# 1     Slightly dissatisfied
# 2            Very satisfied
# 3                       NaN
# 4            Very satisfied
# ...                     ...
# 8398                    NaN
# 8399                    NaN
# 8400                    NaN
# 8401                    NaN
# 8402                    NaN
#
#                                                 JobSeek  \
# 0     I’m not actively looking, but I am open to new...
# 1                       I am actively looking for a job
# 2          I am not interested in new job opportunities
# 3                       I am actively looking for a job
# 4          I am not interested in new job opportunities
# ...                                                 ...
# 8398                                                NaN
# 8399                                                NaN
# 8400                                                NaN
# 8401                                                NaN
# 8402                                                NaN
#
#                            LanguageDesireNextYear  \
# 0                                 C#;HTML/CSS;PHP
# 1                          Java;JavaScript;Python
# 2                    C#;JavaScript;SQL;TypeScript
# 3                            Go;Kotlin;TypeScript
# 4     Bash/Shell/PowerShell;C;C++;Java;Perl;Scala
# ...                                           ...
# 8398          HTML/CSS;Java;JavaScript;Python;SQL
# 8399                                          NaN
# 8400                                          NaN
# 8401                                          NaN
# 8402                                          NaN
#
#                              LanguageWorkedWith  \
# 0                               C#;HTML/CSS;PHP
# 1                                   Java;Python
# 2                  C#;JavaScript;SQL;TypeScript
# 3         C;C++;HTML/CSS;Java;JavaScript;Python
# 4                Bash/Shell/PowerShell;C++;Perl
# ...                                         ...
# 8398  C;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 8399                                        NaN
# 8400                                        NaN
# 8401                                        SQL
# 8402                                        NaN
#
#                        MiscTechDesireNextYear      MiscTechWorkedWith  \
# 0                                         NaN                     NaN
# 1                                         NaN                     NaN
# 2                      .NET;.NET Core;Node.js  .NET;.NET Core;Node.js
# 3     Flutter;Node.js;React Native;TensorFlow                     NaN
# 4                                Apache Spark                     NaN
# ...                                       ...                     ...
# 8398                                      NaN                     NaN
# 8399                                      NaN                     NaN
# 8400                                      NaN                     NaN
# 8401                                      NaN                     NaN
# 8402                                      NaN                     NaN
#
#                            NEWCollabToolsDesireNextYear  \
# 0                                                   NaN
# 1                                                   NaN
# 2                              Stack Overflow for Teams
# 3                   Confluence;Stack Overflow for Teams
# 4     Confluence;Jira;Github;Gitlab;Google Suite (Do...
# ...                                                 ...
# 8398                           Jira;Github;Gitlab;Slack
# 8399                                                NaN
# 8400                                                NaN
# 8401                                                NaN
# 8402                                                NaN
#
#                                NEWCollabToolsWorkedWith NEWDevOps  \
# 0                                                   NaN       Yes
# 1                                                   NaN  Not sure
# 2                              Stack Overflow for Teams       Yes
# 3     Github;Facebook Workplace;Slack;Microsoft Team...       NaN
# 4     Confluence;Jira;Github;Google Suite (Docs, Mee...  Not sure
# ...                                                 ...       ...
# 8398                           Jira;Github;Gitlab;Slack       NaN
# 8399                                                NaN       NaN
# 8400                                                NaN       NaN
# 8401                                                NaN       NaN
# 8402                                                NaN       NaN
#
#             NEWDevOpsImpt             NEWEdImpt  \
# 0     Extremely important        Very important
# 1                     NaN        Very important
# 2     Extremely important        Very important
# 3                     NaN                   NaN
# 4                 Neutral  Critically important
# ...                   ...                   ...
# 8398                  NaN                   NaN
# 8399                  NaN                   NaN
# 8400                  NaN                   NaN
# 8401                  NaN                   NaN
# 8402                  NaN                   NaN
#
#                                              NEWJobHunt  \
# 0     Better compensation;Growth or leadership oppor...
# 1     Better compensation;Better work/life balance;W...
# 2                                                   NaN
# 3                                                   NaN
# 4     Just because;Curious about other opportunities...
# ...                                                 ...
# 8398                                                NaN
# 8399                                                NaN
# 8400                                                NaN
# 8401                                                NaN
# 8402                                                NaN
#
#                                      NEWJobHuntResearch              NEWLearn  \
# 0     Read company media, such as employee blogs or ...      Every few months
# 1     Company reviews from third party sites (e.g. G...      Every few months
# 2                                                   NaN  Once every few years
# 3                                                   NaN           Once a year
# 4     Read company media, such as employee blogs or ...           Once a year
# ...                                                 ...                   ...
# 8398                                                NaN           Once a year
# 8399                                                NaN                   NaN
# 8400                                                NaN                   NaN
# 8401                                                NaN                   NaN
# 8402                                                NaN                   NaN
#
#      NEWOffTopic                NEWOnboardGood NEWOtherComms  \
# 0            Yes                           Yes            No
# 1             No                           Yes            No
# 2            NaN                           Yes            No
# 3            Yes                           NaN            No
# 4       Not sure  Onboarding? What onboarding?            No
# ...          ...                           ...           ...
# 8398          No                           NaN           NaN
# 8399         NaN                           NaN           NaN
# 8400         NaN                           NaN           NaN
# 8401         NaN                           NaN           NaN
# 8402         NaN                           NaN           NaN
#
#                                             NEWOvertime  \
# 0     Sometimes: 1-2 days per month but less than we...
# 1                      Often: 1-2 days per week or more
# 2                      Often: 1-2 days per week or more
# 3                                                   NaN
# 4     Sometimes: 1-2 days per month but less than we...
# ...                                                 ...
# 8398                                                NaN
# 8399                                                NaN
# 8400                                                NaN
# 8401                                                NaN
# 8402                                                NaN
#
#                                     NEWPurchaseResearch      NEWPurpleLink  \
# 0     Start a free trial;Ask developers I know/work ...                NaN
# 1                                                   NaN                NaN
# 2                       Ask developers I know/work with  Hello, old friend
# 3     Start a free trial;Ask developers I know/work ...  Hello, old friend
# 4                                                   NaN        Indifferent
# ...                                                 ...                ...
# 8398                    Ask developers I know/work with             Amused
# 8399                                                NaN                NaN
# 8400                                                NaN                NaN
# 8401                                                NaN                NaN
# 8402                                                NaN                NaN
#
#                                              NEWSOSites  \
# 0      Stack Overflow (public Q&A for anyone who codes)
# 1     Stack Overflow (public Q&A for anyone who code...
# 2     Stack Overflow (public Q&A for anyone who code...
# 3     Stack Overflow (public Q&A for anyone who code...
# 4      Stack Overflow (public Q&A for anyone who codes)
# ...                                                 ...
# 8398  Stack Overflow (public Q&A for anyone who code...
# 8399                                                NaN
# 8400                                                NaN
# 8401                                                NaN
# 8402                                                NaN
#
#                                                NEWStuck        OpSys  \
# 0                                                   NaN      Windows
# 1                                                   NaN      Windows
# 2     Call a coworker or friend;Visit Stack Overflow...      Windows
# 3     Visit Stack Overflow;Go for a walk or other ph...      Windows
# 4     Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# ...                                                 ...          ...
# 8398                               Visit Stack Overflow  Linux-based
# 8399                                                NaN          NaN
# 8400                                                NaN          NaN
# 8401                                                NaN          NaN
# 8402                                                NaN          NaN
#
#                    OrgSize       PlatformDesireNextYear  \
# 0       20 to 99 employees                          NaN
# 1     500 to 999 employees                          NaN
# 2                      NaN                          NaN
# 3                      NaN        AWS;Docker;Heroku;iOS
# 4     500 to 999 employees  Google Cloud Platform;Linux
# ...                    ...                          ...
# 8398                   NaN                Linux;Windows
# 8399                   NaN                          NaN
# 8400                   NaN                          NaN
# 8401                   NaN                          NaN
# 8402                   NaN                          NaN
#
#                                      PlatformWorkedWith  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Android;Arduino;Google Cloud Platform;Raspberr...
# 4                                                 Linux
# ...                                                 ...
# 8398                                      Linux;Windows
# 8399                                                NaN
# 8400                                                NaN
# 8401                                                NaN
# 8402                                                NaN
#
#                        PurchaseWhat                Sexuality  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN  Straight / Heterosexual
# 4     I have little or no influence  Straight / Heterosexual
# ...                             ...                      ...
# 8398                            NaN  Straight / Heterosexual
# 8399                            NaN                      NaN
# 8400                            NaN                      NaN
# 8401                            NaN                      NaN
# 8402                            NaN                      NaN
#
#                     SOAccount           SOComm  \
# 0                         Yes  Yes, definitely
# 1                         Yes  Yes, definitely
# 2                         Yes  Yes, definitely
# 3                         Yes          Neutral
# 4                         Yes    Yes, somewhat
# ...                       ...              ...
# 8398  Not sure/can't remember          Neutral
# 8399                      NaN              NaN
# 8400                      NaN              NaN
# 8401                      NaN              NaN
# 8402                      NaN              NaN
#
#                            SOPartFreq                      SOVisitFreq  \
# 0              Multiple times per day           Multiple times per day
# 1              Multiple times per day           Multiple times per day
# 2                                 NaN           Multiple times per day
# 3                A few times per week            Daily or almost daily
# 4     A few times per month or weekly           Multiple times per day
# ...                               ...                              ...
# 8398                              NaN  A few times per month or weekly
# 8399                              NaN                              NaN
# 8400                              NaN                              NaN
# 8401                              NaN                              NaN
# 8402                              NaN                              NaN
#
#                       SurveyEase           SurveyLength Trans  \
# 0                            NaN                    NaN   NaN
# 1                           Easy  Appropriate in length   NaN
# 2     Neither easy nor difficult               Too long   NaN
# 3                           Easy  Appropriate in length    No
# 4     Neither easy nor difficult  Appropriate in length    No
# ...                          ...                    ...   ...
# 8398                        Easy  Appropriate in length    No
# 8399                         NaN                    NaN   NaN
# 8400                         NaN                    NaN   NaN
# 8401                         NaN                    NaN   NaN
# 8402                         NaN                    NaN   NaN
#
#                                          UndergradMajor  \
# 0     Computer science, computer engineering, or sof...
# 1     Computer science, computer engineering, or sof...
# 2                         Web development or web design
# 3                                                   NaN
# 4     Computer science, computer engineering, or sof...
# ...                                                 ...
# 8398  Computer science, computer engineering, or sof...
# 8399                                                NaN
# 8400                           I never declared a major
# 8401                                                NaN
# 8402                                                NaN
#
#                               WebframeDesireNextYear  \
# 0                                                NaN
# 1                                                NaN
# 2     Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 3            Angular.js;Django;jQuery;Laravel;Vue.js
# 4                                                NaN
# ...                                              ...
# 8398                                          jQuery
# 8399                                             NaN
# 8400                                             NaN
# 8401                                             NaN
# 8402                                             NaN
#
#                                      WebframeWorkedWith  \
# 0                                                   NaN
# 1                                                   NaN
# 2        Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8398                                             jQuery
# 8399                                                NaN
# 8400                                                NaN
# 8401  ASP.NET;ASP.NET Core;Django;jQuery;Symfony;Vue.js
# 8402                                                NaN
#
#                                           WelcomeChange  WorkWeekHrs  \
# 0                 A lot more welcome now than last year          NaN
# 1               Just as welcome now as I felt last year         50.0
# 2                                                   NaN          NaN
# 3     Not applicable - I did not use Stack Overflow ...          NaN
# 4              Somewhat more welcome now than last year         70.0
# ...                                                 ...          ...
# 8398              A lot less welcome now than last year          NaN
# 8399                                                NaN          NaN
# 8400                                                NaN          NaN
# 8401                                                NaN          NaN
# 8402                                                NaN          NaN
#
#      YearsCode      YearsCodePro
# 0            6                 4
# 1           10                 2
# 2          NaN               NaN
# 3            4               NaN
# 4            5                 3
# ...        ...               ...
# 8398         5  Less than 1 year
# 8399       NaN               NaN
# 8400       NaN               NaN
# 8401       NaN               NaN
# 8402       NaN               NaN
#
# [8403 rows x 61 columns]
